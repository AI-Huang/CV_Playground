# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Date    : Nov-16-22 13:47
# @Author  : Kan HUANG (kan.huang@connect.ust.hk)

import sys
sys.path.append("../..")
import tensorflow as tf
from models.tf_fn.resnet_cifar10 import create_resnet_cifar10

# %%
n = 3
depth = 6*n + 2
model = create_resnet_cifar10(input_shape=(32, 32, 3), depth=depth)
# Out:
# 2022-11-25 17:55:45.164645: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-25 17:55:45.207033: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fab26859c20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-11-25 17:55:45.207060: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
model.summary()
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...
